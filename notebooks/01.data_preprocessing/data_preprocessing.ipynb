# %%
import pandas as pd

import warnings
warnings.filterwarnings('ignore')

# %%
# load dataset
dataset = pd.read_csv('../../data/raw/wfp_food_prices_moz.csv')

# %%
dataset.head()
# Out:
#          date       admin1            admin2            market    latitude  \
# 0       #date   #adm1+name        #adm2+name  #loc+market+name    #geo+lat
# 1  1992-11-15  Maputo City  Cidade_De_Maputo            Maputo  -25.965278
# 2  1992-12-15         Gaza            Chokwe            Chokwe  -24.533333
# 3  1992-12-15    Inhambane            Maxixe            Maxixe  -23.859722
# 4  1992-12-15  Maputo City  Cidade_De_Maputo            Maputo  -25.965278
#
#    longitude            category      commodity        unit         priceflag  \
# 0   #geo+lon          #item+type     #item+name  #item+unit  #item+price+flag
# 1  32.589167  cereals and tubers  Maize (white)          KG            actual
# 2  32.983333  cereals and tubers  Maize (white)          KG            actual
# 3  35.347222  cereals and tubers  Maize (white)          KG            actual
# 4  32.589167  cereals and tubers  Maize (white)          KG            actual
#
#           pricetype   currency   price    usdprice
# 0  #item+price+type  #currency  #value  #value+usd
# 1            Retail        MZN    1.34      0.4641
# 2            Retail        MZN    1.53      0.5193
# 3            Retail        MZN    1.69      0.5736
# 4            Retail        MZN    1.55      0.5261

# %%
dataset.tail()
# Out:
#              date    admin1  admin2  market latitude  longitude  \
# 69095  2023-04-15  Zambezia  Mocuba  Mocuba -16.8375  36.985556
# 69096  2023-04-15  Zambezia  Mocuba  Mocuba -16.8375  36.985556
# 69097  2023-04-15  Zambezia  Mocuba  Mocuba -16.8375  36.985556
# 69098  2023-04-15  Zambezia  Mocuba  Mocuba -16.8375  36.985556
# 69099  2023-04-15  Zambezia  Mocuba  Mocuba -16.8375  36.985556
#
#               category                    commodity unit priceflag pricetype  \
# 69095  pulses and nuts               Beans (butter)   KG  forecast    Retail
# 69096  pulses and nuts             Beans (catarino)   KG  forecast    Retail
# 69097  pulses and nuts               Beans (magnum)   KG  forecast    Retail
# 69098  pulses and nuts                      Cowpeas   KG  forecast    Retail
# 69099  pulses and nuts  Groundnuts (small, shelled)   KG  forecast    Retail
#
#       currency price usdprice
# 69095      MZN   0.0      0.0
# 69096      MZN   0.0      0.0
# 69097      MZN   0.0      0.0
# 69098      MZN   0.0      0.0
# 69099      MZN   0.0      0.0

# %%
dataset.describe()
# Out:
#               date     admin1            admin2  market    latitude  \
# count        69100      69098             69098   69100       69098
# unique         362         12                82     100         158
# top     2022-06-15  Inhambane  Cidade_De_Maputo  Maputo  -25.965278
# freq          1356      10457              4390    3053        2976
#
#         longitude            category      commodity   unit priceflag  \
# count       69098               69100          69100  69100     69100
# unique        158                   8             58      8         3
# top     32.589167  cereals and tubers  Maize (white)     KG    actual
# freq         2976               27452           6176  58450     60120
#
#        pricetype currency  price usdprice
# count      69100    69100  69100    69100
# unique         3        2   5943    16325
# top       Retail      MZN    0.0      0.0
# freq       68267    69099   5415     5415

# %%
# dataset shape
print(f"rows: {dataset.shape[0]}")
print(f"columns: {dataset.shape[1]}")
print()

# check for null values
print('null values:')
print(dataset.isnull().sum())
# Out:
# rows: 69100
# columns: 14
#
# null values:
# date         0
# admin1       2
# admin2       2
# market       0
# latitude     2
# longitude    2
# category     0
# commodity    0
# unit         0
# priceflag    0
# pricetype    0
# currency     0
# price        0
# usdprice     0
# dtype: int64

# %%
# drop the first and empty rows
dataset.drop(0, inplace=True)
dataset = dataset.dropna()

# %%
# check data types
dataset.dtypes
# Out:
# date         object
# admin1       object
# admin2       object
# market       object
# latitude     object
# longitude    object
# category     object
# commodity    object
# unit         object
# priceflag    object
# pricetype    object
# currency     object
# price        object
# usdprice     object
# dtype: object

# %%
# Convert types
dataset['price'] = dataset['price'].astype(float)
dataset['latitude'] = dataset['latitude'].astype(float)
dataset['longitude'] = dataset['longitude'].astype(float)

dataset['date'] = pd.to_datetime(dataset['date'])

dataset['year'] = dataset['date'].dt.year
dataset['month'] = dataset['date'].dt.month

dataset.drop('date', axis=1, inplace=True)

# %%
# Drop rows without current prices
dataset = dataset[dataset['priceflag'] != 'forecast']

# %%
dataset['priceflag'].unique()
# Out:
# array(['actual'], dtype=object)

# %%
dataset['commodity'].unique()
# Out:
# array(['Maize (white)', 'Cassava (dry)', 'Rice', 'Rice (imported)',
#        'Sugar (brown, local)', 'Oil (vegetable, local)', 'Beans (dry)',
#        'Groundnuts (Mix)', 'Maize meal (white, first grade)',
#        'Maize meal (white, with bran)', 'Oil (vegetable, imported)',
#        'Cowpeas', 'Groundnuts (large, shelled)',
#        'Groundnuts (small, shelled)', 'Wheat flour (local)',
#        'Cassava flour', 'Cassava (fresh)',
#        'Maize meal (white, without bran)', 'Potatoes (Irish, imported)',
#        'Potatoes (Irish, local)', 'Rice (local)', 'Sweet potatoes',
#        'Cabbage', 'Carrots', 'Garlic (large)', 'Garlic (small)',
#        'Onions (local)', 'Peppers (green)', 'Tomatoes', 'Onions',
#        'Beans (fresh)', 'Potatoes (unica)', 'Maize (imported)',
#        'Beans (red)', 'Beans (butter)', 'Beans (catarino)',
#        'Beans (magnum)', 'Sugar (brown, imported)', 'Onions (imported)',
#        'Maize meal', 'Potatoes', 'Eggs', 'Fish', 'Salt (iodised)',
#        'Sugar', 'Firewood', 'Handwash soap', 'Oil (vegetable)',
#        'Groundnuts', 'Cassava leaves', 'Coconut', 'Garlic', 'Kale',
#        'Sesame', 'Soybeans'], dtype=object)

# %%
dataset.drop(['usdprice', 'currency', 'priceflag'], axis=1, inplace=True)

# %%
dataset.rename(columns={
    'admin1': 'province',
    'admin2': 'district',
    'price': 'price(MZN)',
}, inplace=True)

# %%
print('dataset new shape: ', dataset.shape)
# Out:
# dataset new shape:  (60118, 12)

# %%
dataset.head()
# Out:
#       province          district  market   latitude  longitude  \
# 1  Maputo City  Cidade_De_Maputo  Maputo -25.965278  32.589167
# 2         Gaza            Chokwe  Chokwe -24.533333  32.983333
# 3    Inhambane            Maxixe  Maxixe -23.859722  35.347222
# 4  Maputo City  Cidade_De_Maputo  Maputo -25.965278  32.589167
# 5         Gaza            Chokwe  Chokwe -24.533333  32.983333
#
#              category      commodity unit pricetype  price(MZN)  year  month
# 1  cereals and tubers  Maize (white)   KG    Retail        1.34  1992     11
# 2  cereals and tubers  Maize (white)   KG    Retail        1.53  1992     12
# 3  cereals and tubers  Maize (white)   KG    Retail        1.69  1992     12
# 4  cereals and tubers  Maize (white)   KG    Retail        1.55  1992     12
# 5  cereals and tubers  Maize (white)   KG    Retail        1.67  1993      1

# %%
dataset.tail()
# Out:
#        province district  market  latitude  longitude         category  \
# 60116  Zambezia   Mocuba  Mocuba  -16.8375  36.985556  pulses and nuts
# 60117  Zambezia   Mocuba  Mocuba  -16.8375  36.985556  pulses and nuts
# 60118  Zambezia   Mocuba  Mocuba  -16.8375  36.985556  pulses and nuts
# 60119  Zambezia   Mocuba  Mocuba  -16.8375  36.985556  pulses and nuts
# 60120  Zambezia   Mocuba  Mocuba  -16.8375  36.985556  pulses and nuts
#
#                          commodity unit pricetype  price(MZN)  year  month
# 60116             Beans (catarino)   KG    Retail        80.0  2023      2
# 60117               Beans (magnum)   KG    Retail       100.0  2023      2
# 60118                      Cowpeas   KG    Retail        37.5  2023      2
# 60119  Groundnuts (small, shelled)   KG    Retail        60.0  2023      2
# 60120                       Sesame   KG    Retail       100.0  2023      2

# %%
# save new dataset
dataset.to_csv('../../data/processed/wfp_food_prices_moz.csv', index=False)
